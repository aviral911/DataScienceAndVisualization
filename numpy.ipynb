# %% [markdown]
# <a href="https://colab.research.google.com/github/aviral911/DataScienceAndVisualization/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/students - students.csv")

# %%
df.head()
# Out:
#   student_id   student_name  gender   age  semester  attendance_percent  \
# 0      DS001   Nisha Pandey    Male  22.0         7                62.0
# 1      DS002  Aarav Chauhan  Female  23.0         7                74.4
# 2      DS003   Aditya Gupta  Female  20.0         7                75.3
# 3      DS004   Aditya Kumar    Male  21.0         4                84.8
# 4      DS005    Neha Pandey  Female  23.0         6                57.0
#
#    study_hours_per_day  assignment_average  quiz_average  mid_sem_score  ...  \
# 0                  1.8                48.2          92.0           74.1  ...
# 1                  2.5                78.7          48.4           54.0  ...
# 2                  1.1                96.8          73.8           60.1  ...
# 3                  2.6                73.6          72.8           47.0  ...
# 4                  2.6                66.4          56.3           88.9  ...
#
#    lab_hours_per_week  online_activity_count  projects_completed  \
# ...

# %%
df.tail(10)
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 190      DS191    Riya Chauhan    Male  22.0         4                87.2
# 191      DS192      Isha Sinha    Male  20.0         4                69.1
# 192      DS193  Saurabh Mishra    Male  22.0         7                94.4
# 193      DS194     Rohan Yadav    Male  21.0         3                76.4
# 194      DS195     Rahul Yadav    Male  23.0         3                90.8
# 195      DS196     Aarav Verma  Female  22.0         6                56.9
# 196      DS197   Arjun Chauhan    Male  20.0         3                88.1
# 197      DS198      Neha Kumar  Female  21.0         4                93.6
# 198      DS199     Priya Gupta    Male  21.0         7                98.8
# 199      DS200    Vivaan Singh    Male  21.0         7                88.6
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %%
df.describe()
# Out:
#               age    semester  attendance_percent  study_hours_per_day  \
# count  198.000000  200.000000          200.000000           200.000000
# mean    20.590909    5.580000           77.457500             3.428500
# std      1.744991    1.657509           12.294528             1.473156
# min     18.000000    3.000000           55.000000             1.000000
# 25%     19.000000    4.000000           67.150000             2.200000
# 50%     21.000000    6.000000           77.950000             3.400000
# 75%     22.000000    7.000000           88.500000             4.600000
# max     23.000000    8.000000           99.800000             6.000000
#
#        assignment_average  quiz_average  mid_sem_score  previous_cgpa  \
# count          196.000000    200.000000     200.000000     200.000000
# mean            72.382143     69.936500      66.056500       7.370100
# std             16.642918     17.479347      18.575319       1.442061
# ...

# %%
df.shape
# Out:
# (200, 21)

# %%
df.columns
# Out:
# Index(['student_id', 'student_name', 'gender', 'age', 'semester',
#        'attendance_percent', 'study_hours_per_day', 'assignment_average',
#        'quiz_average', 'mid_sem_score', 'previous_cgpa', 'lab_hours_per_week',
#        'online_activity_count', 'projects_completed', 'python_skill_level',
#        'mathematics_skill', 'engagement_score', 'predicted_score', 'grade',
#        'risk_level', 'learning_recommendation'],
#       dtype='object')

# %%
df.dtypes
# Out:
# student_id                  object
# student_name                object
# gender                      object
# age                        float64
# semester                     int64
# attendance_percent         float64
# study_hours_per_day        float64
# assignment_average         float64
# quiz_average               float64
# mid_sem_score              float64
# previous_cgpa              float64
# lab_hours_per_week         float64
# online_activity_count        int64
# projects_completed           int64
# python_skill_level          object
# mathematics_skill           object
# engagement_score           float64
# predicted_score            float64
# grade                       object
# risk_level                  object
# learning_recommendation     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               200 non-null    object
#  1   student_name             200 non-null    object
#  2   gender                   200 non-null    object
#  3   age                      198 non-null    float64
#  4   semester                 200 non-null    int64
#  5   attendance_percent       200 non-null    float64
#  6   study_hours_per_day      200 non-null    float64
#  7   assignment_average       196 non-null    float64
#  8   quiz_average             200 non-null    float64
#  9   mid_sem_score            200 non-null    float64
#  10  previous_cgpa            200 non-null    float64
#  11  lab_hours_per_week       199 non-null    float64
#  12  online_activity_count    200 non-null    int64
#  13  projects_completed       200 non-null    int64
# ...

# %%
df.describe()
# Out:
#               age    semester  attendance_percent  study_hours_per_day  \
# count  198.000000  200.000000          200.000000           200.000000
# mean    20.590909    5.580000           77.457500             3.428500
# std      1.744991    1.657509           12.294528             1.473156
# min     18.000000    3.000000           55.000000             1.000000
# 25%     19.000000    4.000000           67.150000             2.200000
# 50%     21.000000    6.000000           77.950000             3.400000
# 75%     22.000000    7.000000           88.500000             4.600000
# max     23.000000    8.000000           99.800000             6.000000
#
#        assignment_average  quiz_average  mid_sem_score  previous_cgpa  \
# count          196.000000    200.000000     200.000000     200.000000
# mean            72.382143     69.936500      66.056500       7.370100
# std             16.642918     17.479347      18.575319       1.442061
# ...

# %%
df.isnull()
# Out:
#      student_id  student_name  gender    age  semester  attendance_percent  \
# 0         False         False   False  False     False               False
# 1         False         False   False  False     False               False
# 2         False         False   False  False     False               False
# 3         False         False   False  False     False               False
# 4         False         False   False  False     False               False
# ..          ...           ...     ...    ...       ...                 ...
# 195       False         False   False  False     False               False
# 196       False         False   False  False     False               False
# 197       False         False   False  False     False               False
# 198       False         False   False  False     False               False
# 199       False         False   False  False     False               False
#
# ...

# %%
df.nunique()
# Out:
# student_id                 200
# student_name               123
# gender                       2
# age                          6
# semester                     6
# attendance_percent         166
# study_hours_per_day         51
# assignment_average         160
# quiz_average               171
# mid_sem_score              171
# previous_cgpa              165
# lab_hours_per_week          75
# online_activity_count      130
# projects_completed           6
# python_skill_level           3
# mathematics_skill            3
# engagement_score           170
# predicted_score            146
# grade                        4
# risk_level                   3
# learning_recommendation      4
# dtype: int64

# %%
df.dtypes
# Out:
# student_id                  object
# student_name                object
# gender                      object
# age                        float64
# semester                     int64
# attendance_percent         float64
# study_hours_per_day        float64
# assignment_average         float64
# quiz_average               float64
# mid_sem_score              float64
# previous_cgpa              float64
# lab_hours_per_week         float64
# online_activity_count        int64
# projects_completed           int64
# python_skill_level          object
# mathematics_skill           object
# engagement_score           float64
# predicted_score            float64
# grade                       object
# risk_level                  object
# learning_recommendation     object
# dtype: object

# %%
df[['student_name', 'gender', 'semester']]
# Out:
#       student_name  gender  semester
# 0     Nisha Pandey    Male         7
# 1    Aarav Chauhan  Female         7
# 2     Aditya Gupta  Female         7
# 3     Aditya Kumar    Male         4
# 4      Neha Pandey  Female         6
# ..             ...     ...       ...
# 195    Aarav Verma  Female         6
# 196  Arjun Chauhan    Male         3
# 197     Neha Kumar  Female         4
# 198    Priya Gupta    Male         7
# 199   Vivaan Singh    Male         7
#
# [200 rows x 3 columns]

# %%
df[df['semester'] == 3]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 17       DS018    Arjun Sharma    Male  18.0         3                99.8
# 18       DS019    Aarav Sharma  Female   NaN         3                72.8
# 31       DS032    Ananya Singh    Male  21.0         3                89.3
# 38       DS039      Riya Kumar  Female  19.0         3                73.7
# 39       DS040      Riya Gupta    Male  23.0         3                60.8
# 44       DS045     Rahul Kumar    Male  22.0         3                71.0
# 60       DS061   Kunal Chauhan    Male  21.0         3                55.2
# 64       DS065   Simran Mishra    Male  22.0         3                79.8
# 77       DS078      Riya Gupta    Male  21.0         3                81.1
# 94       DS095     Aryan Singh  Female  21.0         3                78.3
# 95       DS096  Saurabh Mishra  Female  21.0         3                97.8
# ...

# %%
df[df['gender'] == 'Female']
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 1        DS002   Aarav Chauhan  Female  23.0         7                74.4
# 2        DS003    Aditya Gupta  Female  20.0         7                75.3
# 4        DS005     Neha Pandey  Female  23.0         6                57.0
# 6        DS007    Aarav Mishra  Female  23.0         7                87.8
# 7        DS008    Sneha Sharma  Female  18.0         6                80.3
# ..         ...             ...     ...   ...       ...                 ...
# 184      DS185     Pooja Singh  Female  18.0         5                64.5
# 187      DS188  Vivaan Chauhan  Female  22.0         6                93.9
# 189      DS190      Neha Yadav  Female  23.0         6                61.4
# 195      DS196     Aarav Verma  Female  22.0         6                56.9
# 197      DS198      Neha Kumar  Female  21.0         4                93.6
#
# ...

# %%
df[df['previous_cgpa'] > 8.0]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 0        DS001    Nisha Pandey    Male  22.0         7                62.0
# 3        DS004    Aditya Kumar    Male  21.0         4                84.8
# 6        DS007    Aarav Mishra  Female  23.0         7                87.8
# 9        DS010     Nisha Sinha    Male  20.0         8                78.0
# 12       DS013    Aditya Verma  Female  21.0         5                64.9
# ..         ...             ...     ...   ...       ...                 ...
# 192      DS193  Saurabh Mishra    Male  22.0         7                94.4
# 193      DS194     Rohan Yadav    Male  21.0         3                76.4
# 196      DS197   Arjun Chauhan    Male  20.0         3                88.1
# 198      DS199     Priya Gupta    Male  21.0         7                98.8
# 199      DS200    Vivaan Singh    Male  21.0         7                88.6
#
# ...

# %%
df[df['attendance_percent']<75]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 0        DS001   Nisha Pandey    Male  22.0         7                62.0
# 1        DS002  Aarav Chauhan  Female  23.0         7                74.4
# 4        DS005    Neha Pandey  Female  23.0         6                57.0
# 5        DS006     Aman Sinha    Male  18.0         6                68.2
# 10       DS011   Nisha Mishra  Female  19.0         5                68.5
# ..         ...            ...     ...   ...       ...                 ...
# 182      DS183     Isha Gupta    Male  23.0         5                73.3
# 184      DS185    Pooja Singh  Female  18.0         5                64.5
# 189      DS190     Neha Yadav  Female  23.0         6                61.4
# 191      DS192     Isha Sinha    Male  20.0         4                69.1
# 195      DS196    Aarav Verma  Female  22.0         6                56.9
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %%
df[df['study_hours_per_day']>4]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 6        DS007   Aarav Mishra  Female  23.0         7                87.8
# 7        DS008   Sneha Sharma  Female  18.0         6                80.3
# 12       DS013   Aditya Verma  Female  21.0         5                64.9
# 13       DS014  Simran Mishra    Male  23.0         4                66.6
# 15       DS016    Kavya Singh  Female  19.0         8                75.2
# ..         ...            ...     ...   ...       ...                 ...
# 189      DS190     Neha Yadav  Female  23.0         6                61.4
# 191      DS192     Isha Sinha    Male  20.0         4                69.1
# 194      DS195    Rahul Yadav    Male  23.0         3                90.8
# 195      DS196    Aarav Verma  Female  22.0         6                56.9
# 198      DS199    Priya Gupta    Male  21.0         7                98.8
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %%
df[df['python_skill_level']=='Advanced']
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 0        DS001    Nisha Pandey    Male  22.0         7                62.0
# 3        DS004    Aditya Kumar    Male  21.0         4                84.8
# 5        DS006      Aman Sinha    Male  18.0         6                68.2
# 12       DS013    Aditya Verma  Female  21.0         5                64.9
# 13       DS014   Simran Mishra    Male  23.0         4                66.6
# 14       DS015    Kunal Sharma    Male  20.0         5                93.5
# 25       DS026   Nisha Chauhan  Female  19.0         5                77.6
# 36       DS037   Aryan Chauhan  Female  21.0         4                67.0
# 41       DS042    Vivaan Yadav  Female  19.0         4                83.6
# 46       DS047   Aditya Mishra    Male  23.0         5                78.9
# 48       DS049     Rahul Verma    Male  19.0         4                66.0
# ...

# %%
df[df['grade']=='A']
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 14       DS015    Kunal Sharma    Male  20.0         5                93.5
# 16       DS017      Isha Yadav  Female  23.0         8                81.5
# 17       DS018    Arjun Sharma    Male  18.0         3                99.8
# 19       DS020     Aarav Sinha  Female  20.0         8                71.2
# 28       DS029   Saurabh Gupta  Female  18.0         5                99.6
# 35       DS036      Neha Kumar  Female  22.0         8                81.3
# 49       DS050    Kunal Mishra  Female  20.0         5                55.8
# 52       DS053   Ananya Pandey    Male  23.0         5                70.7
# 53       DS054     Aryan Sinha  Female  22.0         8                91.0
# 55       DS056     Aman Sharma    Male  19.0         6                90.7
# 69       DS070    Rahul Pandey    Male  19.0         6                83.5
# ...

# %%
df[df['risk_level']=='High']
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 0        DS001   Nisha Pandey    Male  22.0         7                62.0
# 4        DS005    Neha Pandey  Female  23.0         6                57.0
# 12       DS013   Aditya Verma  Female  21.0         5                64.9
# 20       DS021   Kavya Sharma  Female  21.0         4                59.2
# 33       DS034   Aditya Singh  Female  21.0         8                57.5
# 37       DS038     Isha Gupta  Female  18.0         4                58.7
# 39       DS040     Riya Gupta    Male  23.0         3                60.8
# 45       DS046    Arjun Kumar    Male  18.0         5                63.3
# 49       DS050   Kunal Mishra  Female  20.0         5                55.8
# 60       DS061  Kunal Chauhan    Male  21.0         3                55.2
# 72       DS073  Saurabh Sinha  Female  20.0         5                58.5
# 78       DS079    Arjun Singh  Female  23.0         7                56.9
# ...

# %%
df[df['predicted_score'] > 80][['student_name', 'predicted_score']]
# Out:
#       student_name  predicted_score
# 3     Aditya Kumar             80.1
# 6     Aarav Mishra             83.6
# 11    Rahul Mishra             81.2
# 12    Aditya Verma             82.2
# 14    Kunal Sharma             95.9
# ..             ...              ...
# 190   Riya Chauhan             83.6
# 191     Isha Sinha             87.6
# 196  Arjun Chauhan             86.8
# 198    Priya Gupta             92.6
# 199   Vivaan Singh             89.3
#
# [81 rows x 2 columns]

# %%
df[(df["semester"] == 4) & (df["attendance_percent"] > 80)]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 3        DS004    Aditya Kumar    Male  21.0         4                84.8
# 27       DS028    Riya Chauhan    Male  22.0         4                85.7
# 41       DS042    Vivaan Yadav  Female  19.0         4                83.6
# 42       DS043  Saurabh Pandey  Female  18.0         4                89.6
# 67       DS068    Priya Pandey  Female  18.0         4                80.5
# 76       DS077    Simran Kumar    Male  22.0         4                94.4
# 99       DS100    Vivaan Verma  Female  19.0         4                90.7
# 106      DS107    Simran Singh  Female  18.0         4                94.1
# 118      DS119    Aditya Yadav  Female  23.0         4                99.7
# 123      DS124    Simran Verma    Male  19.0         4                92.0
# 141      DS142     Nisha Verma  Female  23.0         4                82.0
# ...

# %%
df[(df["previous_cgpa"] > 8.0) & (df["predicted_score"] > 75)]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 0        DS001    Nisha Pandey    Male  22.0         7                62.0
# 3        DS004    Aditya Kumar    Male  21.0         4                84.8
# 6        DS007    Aarav Mishra  Female  23.0         7                87.8
# 12       DS013    Aditya Verma  Female  21.0         5                64.9
# 14       DS015    Kunal Sharma    Male  20.0         5                93.5
# ..         ...             ...     ...   ...       ...                 ...
# 192      DS193  Saurabh Mishra    Male  22.0         7                94.4
# 193      DS194     Rohan Yadav    Male  21.0         3                76.4
# 196      DS197   Arjun Chauhan    Male  20.0         3                88.1
# 198      DS199     Priya Gupta    Male  21.0         7                98.8
# 199      DS200    Vivaan Singh    Male  21.0         7                88.6
#
# ...

# %%
df[(df["gender"] == "Female") & (df["python_skill_level"] == "Advanced")]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 12       DS013    Aditya Verma  Female  21.0         5                64.9
# 25       DS026   Nisha Chauhan  Female  19.0         5                77.6
# 36       DS037   Aryan Chauhan  Female  21.0         4                67.0
# 41       DS042    Vivaan Yadav  Female  19.0         4                83.6
# 66       DS067    Simran Singh  Female  18.0         7                70.4
# 107      DS108    Vivaan Singh  Female  23.0         3                94.0
# 111      DS112      Neha Sinha  Female  21.0         5                72.1
# 126      DS127    Kavya Sharma  Female  21.0         3                77.9
# 129      DS130     Arjun Singh  Female  21.0         6                84.3
# 134      DS135  Vivaan Chauhan  Female  18.0         4                65.1
# 137      DS138     Isha Mishra  Female  22.0         8                94.3
# ...

# %%
df[df["study_hours_per_day"].between(2, 5)]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 1        DS002  Aarav Chauhan  Female  23.0         7                74.4
# 3        DS004   Aditya Kumar    Male  21.0         4                84.8
# 4        DS005    Neha Pandey  Female  23.0         6                57.0
# 6        DS007   Aarav Mishra  Female  23.0         7                87.8
# 7        DS008   Sneha Sharma  Female  18.0         6                80.3
# ..         ...            ...     ...   ...       ...                 ...
# 194      DS195    Rahul Yadav    Male  23.0         3                90.8
# 195      DS196    Aarav Verma  Female  22.0         6                56.9
# 196      DS197  Arjun Chauhan    Male  20.0         3                88.1
# 197      DS198     Neha Kumar  Female  21.0         4                93.6
# 199      DS200   Vivaan Singh    Male  21.0         7                88.6
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %%
df[df["grade"].isin(["A", "B"])]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 0        DS001   Nisha Pandey    Male  22.0         7                62.0
# 3        DS004   Aditya Kumar    Male  21.0         4                84.8
# 6        DS007   Aarav Mishra  Female  23.0         7                87.8
# 7        DS008   Sneha Sharma  Female  18.0         6                80.3
# 11       DS012   Rahul Mishra  Female  21.0         5                71.6
# ..         ...            ...     ...   ...       ...                 ...
# 194      DS195    Rahul Yadav    Male  23.0         3                90.8
# 195      DS196    Aarav Verma  Female  22.0         6                56.9
# 196      DS197  Arjun Chauhan    Male  20.0         3                88.1
# 198      DS199    Priya Gupta    Male  21.0         7                98.8
# 199      DS200   Vivaan Singh    Male  21.0         7                88.6
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %%
df[df["risk_level"].isin(["Medium", "High"])]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 0        DS001    Nisha Pandey    Male  22.0         7                62.0
# 1        DS002   Aarav Chauhan  Female  23.0         7                74.4
# 4        DS005     Neha Pandey  Female  23.0         6                57.0
# 5        DS006      Aman Sinha    Male  18.0         6                68.2
# 10       DS011    Nisha Mishra  Female  19.0         5                68.5
# ..         ...             ...     ...   ...       ...                 ...
# 184      DS185     Pooja Singh  Female  18.0         5                64.5
# 187      DS188  Vivaan Chauhan  Female  22.0         6                93.9
# 189      DS190      Neha Yadav  Female  23.0         6                61.4
# 191      DS192      Isha Sinha    Male  20.0         4                69.1
# 195      DS196     Aarav Verma  Female  22.0         6                56.9
#
# ...

# %%
df[df["mathematics_skill"].isin(["Good", "Excellent"])]
# Out:
# Empty DataFrame
# Columns: [student_id, student_name, gender, age, semester, attendance_percent, study_hours_per_day, assignment_average, quiz_average, mid_sem_score, previous_cgpa, lab_hours_per_week, online_activity_count, projects_completed, python_skill_level, mathematics_skill, engagement_score, predicted_score, grade, risk_level, learning_recommendation]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[(df["attendance_percent"] > 85) & (df["study_hours_per_day"] > 3) & (df["grade"] == "A")]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 17       DS018   Arjun Sharma    Male  18.0         3                99.8
# 28       DS029  Saurabh Gupta  Female  18.0         5                99.6
# 53       DS054    Aryan Sinha  Female  22.0         8                91.0
# 55       DS056    Aman Sharma    Male  19.0         6                90.7
# 71       DS072    Arjun Verma  Female  20.0         5                92.9
# 73       DS074    Neha Pandey    Male  20.0         7                89.2
# 105      DS106    Nisha Singh    Male  19.0         6                85.3
# 106      DS107   Simran Singh  Female  18.0         4                94.1
# 133      DS134     Riya Verma    Male  23.0         6                89.9
# 198      DS199    Priya Gupta    Male  21.0         7                98.8
# 199      DS200   Vivaan Singh    Male  21.0         7                88.6
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %%
df.sort_values("predicted_score", ascending=False)
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 73       DS074    Neha Pandey    Male  20.0         7                89.2
# 14       DS015   Kunal Sharma    Male  20.0         5                93.5
# 122      DS123  Saurabh Kumar  Female  19.0         8                91.8
# 49       DS050   Kunal Mishra  Female  20.0         5                55.8
# 129      DS130    Arjun Singh  Female  21.0         6                84.3
# ..         ...            ...     ...   ...       ...                 ...
# 72       DS073  Saurabh Sinha  Female  20.0         5                58.5
# 167      DS168    Sneha Kumar    Male  20.0         8                82.5
# 162      DS163     Isha Verma    Male  23.0         8                60.4
# 145      DS146     Aman Singh    Male  20.0         3                90.1
# 94       DS095    Aryan Singh  Female  21.0         3                78.3
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %%
df.sort_values("predicted_score", ascending=False).head(10)
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 73       DS074    Neha Pandey    Male  20.0         7                89.2
# 14       DS015   Kunal Sharma    Male  20.0         5                93.5
# 122      DS123  Saurabh Kumar  Female  19.0         8                91.8
# 49       DS050   Kunal Mishra  Female  20.0         5                55.8
# 129      DS130    Arjun Singh  Female  21.0         6                84.3
# 198      DS199    Priya Gupta    Male  21.0         7                98.8
# 179      DS180     Neha Singh    Male  20.0         6                73.1
# 17       DS018   Arjun Sharma    Male  18.0         3                99.8
# 119      DS120  Pooja Chauhan    Male  23.0         8                75.3
# 19       DS020    Aarav Sinha  Female  20.0         8                71.2
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# 73                   4.6                80.0          98.8           93.7
# ...

# %%
df.sort_values("predicted_score", ascending=True).head(10)
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 94       DS095     Aryan Singh  Female  21.0         3                78.3
# 145      DS146      Aman Singh    Male  20.0         3                90.1
# 162      DS163      Isha Verma    Male  23.0         8                60.4
# 167      DS168     Sneha Kumar    Male  20.0         8                82.5
# 72       DS073   Saurabh Sinha  Female  20.0         5                58.5
# 160      DS161      Isha Kumar  Female  23.0         5                55.0
# 36       DS037   Aryan Chauhan  Female  21.0         4                67.0
# 187      DS188  Vivaan Chauhan  Female  22.0         6                93.9
# 10       DS011    Nisha Mishra  Female  19.0         5                68.5
# 174      DS175     Arjun Kumar  Female  19.0         6                74.4
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %%
df.loc[df["predicted_score"].idxmax()]
# Out:
# student_id                             DS074
# student_name                     Neha Pandey
# gender                                  Male
# age                                     20.0
# semester                                   7
# attendance_percent                      89.2
# study_hours_per_day                      4.6
# assignment_average                      80.0
# quiz_average                            98.8
# mid_sem_score                           93.7
# previous_cgpa                            8.1
# lab_hours_per_week                       5.5
# online_activity_count                    118
# projects_completed                         1
# python_skill_level                  Beginner
# mathematics_skill                     Medium
# engagement_score                        68.5
# predicted_score                         96.3
# grade                                      A
# risk_level                               Low
# learning_recommendation    Advanced Projects
# ...

# %%
df.loc[df["predicted_score"].idxmin()]
# Out:
# student_id                                        DS095
# student_name                                Aryan Singh
# gender                                           Female
# age                                                21.0
# semester                                              3
# attendance_percent                                 78.3
# study_hours_per_day                                 1.4
# assignment_average                                 64.3
# quiz_average                                       42.0
# mid_sem_score                                      40.1
# previous_cgpa                                      6.91
# lab_hours_per_week                                  1.1
# online_activity_count                               112
# projects_completed                                    1
# python_skill_level                         Intermediate
# mathematics_skill                                  High
# engagement_score                                   39.7
# ...
