# %% [markdown]
# <a href="https://colab.research.google.com/github/aviral911/DataScienceAndVisualization/blob/main/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function is a block of code
#user defined & builtin
def great():
  print("wlecome to GLA")
great()
# Out:
# wlecome to GLA

# %%
#add two numer using user def
a = int(input("enter first number: "))
b= int(input("enter second number: "))
def add(a,b):
  print(a+b)
add(a,b)
# Out:
# enter first number: 45
# enter second number: 65
# 110

# %%
principle = int(input("Enter principal: "))
rate = int(input("Enter rate: "))
time = int(input("Enter time: "))

def simple_interest(principle, rate, time):
    return (principle * rate * time) / 100

si = simple_interest(principle, rate, time)

print("Simple Interest =", si)
# Out:
# Enter principal: 4566
# Enter rate: 5
# Enter time: 6
# Simple Interest = 1369.8

# %%
#default argument
def msg1(name , age=22):
  print(name)
  print(age)

# %%
msg1("raj",25)
msg1("ravi")
# Out:
# raj
# 25
# ravi
# 22

# %%
#variable length
def msg2(arg1,*arg2):
  print(arg1)
  for x in arg2:
    print(x)

# %%
msg2(1,2,3,4,5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def add(*numbers):
 total =0
 for num in numbers:
  total = total+num
 print(total)

# %%
add(1,2,3)
# Out:
# 6
